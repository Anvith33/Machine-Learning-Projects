# %% [markdown]
# # Cryptocurrency Price Prediction with Machine Learning

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\lenovo\anaconda3\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (3.0.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: requests>=2.31 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (2.33.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (2026.1.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (6.33.0)
# Requirement already satisfied: websockets>=13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\lenovo\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\lenovo\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\lenovo\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2026.6.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: pycparser in c:\users\lenovo\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=768)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('BTC-USD', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import yfinance as yf
#       3 import datetime
#       4 from datetime import date, timedelta
#
# File ~\anaconda3\Lib\site-packages\yfinance\__init__.py:25
#      23 from .search import Search
#      24 from .lookup import Lookup
# ---> 25 from .ticker import Ticker
#      26 from .tickers import Tickers
#      27 from .multi import download
#
# File ~\anaconda3\Lib\site-packages\yfinance\ticker.py:29
#      25 import warnings
#      27 import pandas as _pd
# ---> 29 from .base import TickerBase
#      30 from .const import _BASE_URL_, _SENTINEL_
#      31 from .scrapers.funds import FundsData
#
# File ~\anaconda3\Lib\site-packages\yfinance\base.py:38
#      36 from .data import YfData
#      37 from .exceptions import YFEarningsDateMissing, YFRateLimitError
# ---> 38 from .live import WebSocket
#      39 from .scrapers.analysis import Analysis
#      40 from .scrapers.fundamentals import Fundamentals
#
# File ~\anaconda3\Lib\site-packages\yfinance\live.py:10
#       7 from websockets.asyncio.client import connect as async_connect
#       9 from yfinance import utils
# ---> 10 from yfinance.pricing_pb2 import PricingData
#      11 from google.protobuf.json_format import MessageToDict
#      14 class BaseWebSocket:
#
# File ~\anaconda3\Lib\site-packages\yfinance\pricing_pb2.py:5
#       1 # -*- coding: utf-8 -*-
#       2 # Generated by the protocol buffer compiler.  DO NOT EDIT!
#       3 # source: pricing.proto
#       4 """Generated protocol buffer code."""
# ----> 5 from google.protobuf import descriptor as _descriptor
#       6 from google.protobuf import descriptor_pool as _descriptor_pool
#       7 from google.protobuf import message as _message
#
# ImportError: cannot import name 'descriptor' from 'google.protobuf' (unknown location)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Python --version
#
# NameError: name 'Python' is not defined

# %%
conda list protobuf
# Out:
# # packages in environment at C:\Users\Lenovo\anaconda3:
# #
# # Name                    Version                   Build  Channel
# protobuf                  6.33.0                   pypi_0    pypi
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list yfinance
# Out:
# # packages in environment at C:\Users\Lenovo\anaconda3:
# #
# # Name                    Version                   Build  Channel
# yfinance                  0.2.66                   pypi_0    pypi
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install --force-reinstall protobuf

# %%
pip uninstall yfinance
pip install yfinance
